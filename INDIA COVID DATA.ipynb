# %%
import numpy as np
import pandas as pd

# %%
c_19_IND_df = pd.read_csv("covid_19_india.csv")

# %%
c_19_IND_df
# Out:
#          Sno        Date     Time State/UnionTerritory  \
# 0          1  2020-01-30  6:00 PM               Kerala
# 1          2  2020-01-31  6:00 PM               Kerala
# 2          3  2020-02-01  6:00 PM               Kerala
# 3          4  2020-02-02  6:00 PM               Kerala
# 4          5  2020-02-03  6:00 PM               Kerala
# ...      ...         ...      ...                  ...
# 16845  16846  2021-07-07  8:00 AM            Telangana
# 16846  16847  2021-07-07  8:00 AM              Tripura
# 16847  16848  2021-07-07  8:00 AM          Uttarakhand
# 16848  16849  2021-07-07  8:00 AM        Uttar Pradesh
# 16849  16850  2021-07-07  8:00 AM          West Bengal
#
#       ConfirmedIndianNational ConfirmedForeignNational    Cured  Deaths  \
# 0                           1                        0        0       0
# 1                           1                        0        0       0
# 2                           2                        0        0       0
# ...

# %%
c_19_IND_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16850 entries, 0 to 16849
# Data columns (total 9 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Sno                       16850 non-null  int64
#  1   Date                      16850 non-null  object
#  2   Time                      16850 non-null  object
#  3   State/UnionTerritory      16850 non-null  object
#  4   ConfirmedIndianNational   16850 non-null  object
#  5   ConfirmedForeignNational  16850 non-null  object
#  6   Cured                     16850 non-null  int64
#  7   Deaths                    16850 non-null  int64
#  8   Confirmed                 16850 non-null  int64
# dtypes: int64(4), object(5)
# memory usage: 1.2+ MB

# %%
c_19_IND_df.describe()
# Out:
#                 Sno         Cured         Deaths     Confirmed
# count  16850.000000  1.685000e+04   16850.000000  1.685000e+04
# mean    8425.500000  2.360353e+05    3485.222552  2.583667e+05
# std     4864.320353  5.225438e+05    9330.541749  5.672808e+05
# min        1.000000  0.000000e+00       0.000000  0.000000e+00
# 25%     4213.250000  2.658500e+03      22.000000  3.644750e+03
# 50%     8425.500000  2.889500e+04     453.000000  3.336150e+04
# 75%    12637.750000  2.537510e+05    3071.250000  2.666530e+05
# max    16850.000000  5.872268e+06  123531.000000  6.113335e+06

# %%
c_19_IND_df.shape    # no of columns and rows..
# Out:
# (16850, 9)

# %%
c_19_IND_df_copy = c_19_IND_df.copy()

# %%
c_19_IND_df_copy
# Out:
#          Sno        Date     Time State/UnionTerritory  \
# 0          1  2020-01-30  6:00 PM               Kerala
# 1          2  2020-01-31  6:00 PM               Kerala
# 2          3  2020-02-01  6:00 PM               Kerala
# 3          4  2020-02-02  6:00 PM               Kerala
# 4          5  2020-02-03  6:00 PM               Kerala
# ...      ...         ...      ...                  ...
# 16845  16846  2021-07-07  8:00 AM            Telangana
# 16846  16847  2021-07-07  8:00 AM              Tripura
# 16847  16848  2021-07-07  8:00 AM          Uttarakhand
# 16848  16849  2021-07-07  8:00 AM        Uttar Pradesh
# 16849  16850  2021-07-07  8:00 AM          West Bengal
#
#       ConfirmedIndianNational ConfirmedForeignNational    Cured  Deaths  \
# 0                           1                        0        0       0
# 1                           1                        0        0       0
# 2                           2                        0        0       0
# ...

# %%
c_19_IND_df_copy.loc[1:20]
# Out:
#     Sno        Date     Time State/UnionTerritory ConfirmedIndianNational  \
# 1     2  2020-01-31  6:00 PM               Kerala                       1
# 2     3  2020-02-01  6:00 PM               Kerala                       2
# 3     4  2020-02-02  6:00 PM               Kerala                       3
# 4     5  2020-02-03  6:00 PM               Kerala                       3
# 5     6  2020-02-04  6:00 PM               Kerala                       3
# 6     7  2020-02-05  6:00 PM               Kerala                       3
# 7     8  2020-02-06  6:00 PM               Kerala                       3
# 8     9  2020-02-07  6:00 PM               Kerala                       3
# 9    10  2020-02-08  6:00 PM               Kerala                       3
# 10   11  2020-02-09  6:00 PM               Kerala                       3
# 11   12  2020-02-10  6:00 PM               Kerala                       3
# 12   13  2020-02-11  6:00 PM               Kerala                       3
# ...

# %%
c_19_IND_df_copy.loc[12828]
# Out:
# Sno                              12829
# Date                        2021-03-18
# Time                           8:00 AM
# State/UnionTerritory           Gujarat
# ConfirmedIndianNational              -
# ConfirmedForeignNational             -
# Cured                           271433
# Deaths                            4430
# Confirmed                       281173
# Name: 12828, dtype: object

# %% [markdown]
# ### not right answer of following it should be 37 according to data.

# %%
c_19_IND_df_copy.Cured.first_valid_index()
# Out:
# 0

# %%
c_19_IND_df_copy.at[37,'Cured']
# Out:
# 3

# %%
type(c_19_IND_df_copy.loc[37])
# Out:
# pandas.core.series.Series

# %%
c_19_IND_df_copy[['Cured','Deaths']][30:41]
# Out:
#     Cured  Deaths
# 30      0       0
# 31      0       0
# 32      0       0
# 33      0       0
# 34      0       0
# 35      0       0
# 36      0       0
# 37      3       0
# 38      0       0
# 39      0       0
# 40      3       0

# %% [markdown]
# ### exact value info

# %%
c_19_IND_df_copy.loc[12321]
# Out:
# Sno                                                            12322
# Date                                                      2021-03-04
# Time                                                         8:00 AM
# State/UnionTerritory        Dadra and Nagar Haveli and Daman and Diu
# ConfirmedIndianNational                                            -
# ConfirmedForeignNational                                           -
# Cured                                                           3400
# Deaths                                                             2
# Confirmed                                                       3408
# Name: 12321, dtype: object

# %%
c_19_IND_df_copy
# Out:
#          Sno        Date     Time State/UnionTerritory  \
# 0          1  2020-01-30  6:00 PM               Kerala
# 1          2  2020-01-31  6:00 PM               Kerala
# 2          3  2020-02-01  6:00 PM               Kerala
# 3          4  2020-02-02  6:00 PM               Kerala
# 4          5  2020-02-03  6:00 PM               Kerala
# ...      ...         ...      ...                  ...
# 16845  16846  2021-07-07  8:00 AM            Telangana
# 16846  16847  2021-07-07  8:00 AM              Tripura
# 16847  16848  2021-07-07  8:00 AM          Uttarakhand
# 16848  16849  2021-07-07  8:00 AM        Uttar Pradesh
# 16849  16850  2021-07-07  8:00 AM          West Bengal
#
#       ConfirmedIndianNational ConfirmedForeignNational    Cured  Deaths  \
# 0                           1                        0        0       0
# 1                           1                        0        0       0
# 2                           2                        0        0       0
# ...

# %% [markdown]
# ### sum and max

# %%
total_cured = c_19_IND_df_copy.groupby('State/UnionTerritory')['Cured'].max().sum()
total_deaths = c_19_IND_df_copy.groupby('State/UnionTerritory')['Deaths'].max().sum()
total_confirmed = c_19_IND_df_copy.groupby('State/UnionTerritory')['Confirmed'].max().sum()

# %%
print(f'Total cure numbers are {total_cured}')
print(f'Total Deaths due to covid 19 is {total_deaths}')
print(f'Total confirm people for covid 19 are {total_confirmed}')
# Out:
# Total cure numbers are 30873189
# Total Deaths due to covid 19 is 415979
# Total confirm people for covid 19 are 31842476

# %% [markdown]
# ### death rate

# %%
death_rate = (total_deaths/total_confirmed)*100
print(death_rate)
# Out:
# 1.3063651206018025

# %%
print('Death Rate of india for Covid 19 is {:.2f} %'.format(death_rate))
# Out:
# Death Rate of india for Covid 19 is 1.31 %

# %% [markdown]
# ### active cases

# %%
active_cases = total_confirmed - (total_cured + total_deaths)

# %%
print(f'Total active cases for covid 19 are {active_cases}')
# Out:
# Total active cases for covid 19 are 553308

# %% [markdown]
# ### recovery rate

# %%
recovery_rate = (total_cured/ total_confirmed) * 100
print('Recovery Rate of india for Covid 19 is {:.2f} %'.format(recovery_rate))
# Out:
# Recovery Rate of india for Covid 19 is 96.96 %

# %%
c_19_IND_df_copy['active_cases'] = (c_19_IND_df_copy.Confirmed - (c_19_IND_df_copy.Cured + c_19_IND_df_copy.Deaths))

# %%
c_19_IND_df_copy
# Out:
#          Sno        Date     Time State/UnionTerritory  \
# 0          1  2020-01-30  6:00 PM               Kerala
# 1          2  2020-01-31  6:00 PM               Kerala
# 2          3  2020-02-01  6:00 PM               Kerala
# 3          4  2020-02-02  6:00 PM               Kerala
# 4          5  2020-02-03  6:00 PM               Kerala
# ...      ...         ...      ...                  ...
# 16845  16846  2021-07-07  8:00 AM            Telangana
# 16846  16847  2021-07-07  8:00 AM              Tripura
# 16847  16848  2021-07-07  8:00 AM          Uttarakhand
# 16848  16849  2021-07-07  8:00 AM        Uttar Pradesh
# 16849  16850  2021-07-07  8:00 AM          West Bengal
#
#       ConfirmedIndianNational ConfirmedForeignNational    Cured  Deaths  \
# 0                           1                        0        0       0
# 1                           1                        0        0       0
# 2                           2                        0        0       0
# ...

# %% [markdown]
# # where all numbers of maharashtra state are there

# %%
(c_19_IND_df_copy.loc[c_19_IND_df_copy['State/UnionTerritory'] =='Maharashtra'])
# Out:
#          Sno        Date     Time State/UnionTerritory  \
# 76        77  2020-03-09  6:00 PM          Maharashtra
# 91        92  2020-03-10  6:00 PM          Maharashtra
# 97        98  2020-03-11  6:00 PM          Maharashtra
# 120      121  2020-03-12  6:00 PM          Maharashtra
# 133      134  2020-03-13  6:00 PM          Maharashtra
# ...      ...         ...      ...                  ...
# 16690  16691  2021-07-03  8:00 AM          Maharashtra
# 16726  16727  2021-07-04  8:00 AM          Maharashtra
# 16762  16763  2021-07-05  8:00 AM          Maharashtra
# 16798  16799  2021-07-06  8:00 AM          Maharashtra
# 16834  16835  2021-07-07  8:00 AM          Maharashtra
#
#       ConfirmedIndianNational ConfirmedForeignNational    Cured  Deaths  \
# 76                          2                        0        0       0
# 91                          5                        0        0       0
# 97                          2                        0        0       0
# ...

# %%
c_19_IND_df_copy.describe()
# Out:
#                 Sno         Cured         Deaths     Confirmed   active_cases
# count  16850.000000  1.685000e+04   16850.000000  1.685000e+04   16850.000000
# mean    8425.500000  2.360353e+05    3485.222552  2.583667e+05   18846.168427
# std     4864.320353  5.225438e+05    9330.541749  5.672808e+05   54267.658198
# min        1.000000  0.000000e+00       0.000000  0.000000e+00   -9368.000000
# 25%     4213.250000  2.658500e+03      22.000000  3.644750e+03     309.250000
# 50%     8425.500000  2.889500e+04     453.000000  3.336150e+04    2394.500000
# 75%    12637.750000  2.537510e+05    3071.250000  2.666530e+05   12838.500000
# max    16850.000000  5.872268e+06  123531.000000  6.113335e+06  701614.000000

# %%
c_19_IND_df_copy
# Out:
#          Sno        Date     Time State/UnionTerritory  \
# 0          1  2020-01-30  6:00 PM               Kerala
# 1          2  2020-01-31  6:00 PM               Kerala
# 2          3  2020-02-01  6:00 PM               Kerala
# 3          4  2020-02-02  6:00 PM               Kerala
# 4          5  2020-02-03  6:00 PM               Kerala
# ...      ...         ...      ...                  ...
# 16845  16846  2021-07-07  8:00 AM            Telangana
# 16846  16847  2021-07-07  8:00 AM              Tripura
# 16847  16848  2021-07-07  8:00 AM          Uttarakhand
# 16848  16849  2021-07-07  8:00 AM        Uttar Pradesh
# 16849  16850  2021-07-07  8:00 AM          West Bengal
#
#       ConfirmedIndianNational ConfirmedForeignNational    Cured  Deaths  \
# 0                           1                        0        0       0
# 1                           1                        0        0       0
# 2                           2                        0        0       0
# ...

# %% [markdown]
# ### isnull...

# %%
c_19_IND_df_copy.isnull()
# Out:
#          Sno   Date   Time  State/UnionTerritory  ConfirmedIndianNational  \
# 0      False  False  False                 False                    False
# 1      False  False  False                 False                    False
# 2      False  False  False                 False                    False
# 3      False  False  False                 False                    False
# 4      False  False  False                 False                    False
# ...      ...    ...    ...                   ...                      ...
# 16845  False  False  False                 False                    False
# 16846  False  False  False                 False                    False
# 16847  False  False  False                 False                    False
# 16848  False  False  False                 False                    False
# 16849  False  False  False                 False                    False
#
#        ConfirmedForeignNational  Cured  Deaths  Confirmed  active_cases
# ...

# %% [markdown]
# ### given value is there or not

# %%
c_19_IND_df_copy.isin(['-'])
# Out:
#          Sno   Date   Time  State/UnionTerritory  ConfirmedIndianNational  \
# 0      False  False  False                 False                    False
# 1      False  False  False                 False                    False
# 2      False  False  False                 False                    False
# 3      False  False  False                 False                    False
# 4      False  False  False                 False                    False
# ...      ...    ...    ...                   ...                      ...
# 16845  False  False  False                 False                     True
# 16846  False  False  False                 False                     True
# 16847  False  False  False                 False                     True
# 16848  False  False  False                 False                     True
# 16849  False  False  False                 False                     True
#
#        ConfirmedForeignNational  Cured  Deaths  Confirmed  active_cases
# ...

# %% [markdown]
# ### replace value

# %%
c_19_IND_df_copy.replace('-',np.nan)
# Out:
#          Sno        Date     Time State/UnionTerritory  \
# 0          1  2020-01-30  6:00 PM               Kerala
# 1          2  2020-01-31  6:00 PM               Kerala
# 2          3  2020-02-01  6:00 PM               Kerala
# 3          4  2020-02-02  6:00 PM               Kerala
# 4          5  2020-02-03  6:00 PM               Kerala
# ...      ...         ...      ...                  ...
# 16845  16846  2021-07-07  8:00 AM            Telangana
# 16846  16847  2021-07-07  8:00 AM              Tripura
# 16847  16848  2021-07-07  8:00 AM          Uttarakhand
# 16848  16849  2021-07-07  8:00 AM        Uttar Pradesh
# 16849  16850  2021-07-07  8:00 AM          West Bengal
#
#       ConfirmedIndianNational ConfirmedForeignNational    Cured  Deaths  \
# 0                           1                        0        0       0
# 1                           1                        0        0       0
# 2                           2                        0        0       0
# ...

# %% [markdown]
# ### condition

# %%
high_cases = c_19_IND_df_copy.Confirmed > 1000

# %%
high_cases
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 16845     True
# 16846     True
# 16847     True
# 16848     True
# 16849     True
# Name: Confirmed, Length: 16850, dtype: bool

# %%
c_19_IND_df_copy[high_cases]
# Out:
#          Sno        Date     Time State/UnionTerritory  \
# 757      758  2020-04-08  5:00 PM          Maharashtra
# 788      789  2020-04-09  5:00 PM          Maharashtra
# 819      820  2020-04-10  5:00 PM          Maharashtra
# 850      851  2020-04-11  5:00 PM          Maharashtra
# 870      871  2020-04-12  5:00 PM                Delhi
# ...      ...         ...      ...                  ...
# 16845  16846  2021-07-07  8:00 AM            Telangana
# 16846  16847  2021-07-07  8:00 AM              Tripura
# 16847  16848  2021-07-07  8:00 AM          Uttarakhand
# 16848  16849  2021-07-07  8:00 AM        Uttar Pradesh
# 16849  16850  2021-07-07  8:00 AM          West Bengal
#
#       ConfirmedIndianNational ConfirmedForeignNational    Cured  Deaths  \
# 757                         -                        -       79      64
# 788                         -                        -      117      72
# 819                         -                        -      125      97
# ...

# %%
high_death_cases = c_19_IND_df_copy[c_19_IND_df_copy.Deaths > 100]

# %%
high_death_cases
# Out:
#          Sno        Date     Time State/UnionTerritory  \
# 850      851  2020-04-11  5:00 PM          Maharashtra
# 881      882  2020-04-12  5:00 PM          Maharashtra
# 912      913  2020-04-13  5:00 PM          Maharashtra
# 944      945  2020-04-14  5:00 PM          Maharashtra
# 977      978  2020-04-15  5:00 PM          Maharashtra
# ...      ...         ...      ...                  ...
# 16845  16846  2021-07-07  8:00 AM            Telangana
# 16846  16847  2021-07-07  8:00 AM              Tripura
# 16847  16848  2021-07-07  8:00 AM          Uttarakhand
# 16848  16849  2021-07-07  8:00 AM        Uttar Pradesh
# 16849  16850  2021-07-07  8:00 AM          West Bengal
#
#       ConfirmedIndianNational ConfirmedForeignNational    Cured  Deaths  \
# 850                         -                        -      188     110
# 881                         -                        -      208     127
# 912                         -                        -      217     149
# ...

# %%
c_19_IND_df_copy.sort_values('Confirmed',ascending=True)
# Out:
#          Sno        Date     Time State/UnionTerritory  \
# 1113    1114  2020-04-19  5:00 PM             Nagaland
# 10171  10172  2021-01-03  8:00 AM          Lakshadweep
# 10207  10208  2021-01-04  8:00 AM          Lakshadweep
# 10243  10244  2021-01-05  8:00 AM          Lakshadweep
# 10279  10280  2021-01-06  8:00 AM          Lakshadweep
# ...      ...         ...      ...                  ...
# 16690  16691  2021-07-03  8:00 AM          Maharashtra
# 16726  16727  2021-07-04  8:00 AM          Maharashtra
# 16762  16763  2021-07-05  8:00 AM          Maharashtra
# 16798  16799  2021-07-06  8:00 AM          Maharashtra
# 16834  16835  2021-07-07  8:00 AM          Maharashtra
#
#       ConfirmedIndianNational ConfirmedForeignNational    Cured  Deaths  \
# 1113                        -                        -        0       0
# 10171                       -                        -        0       0
# 10207                       -                        -        0       0
# ...

# %%
c_19_IND_df_copy['Confirmed'].mean()
# Out:
# 258366.6512759644

# %%
c_19_IND_df_copy.Date
# Out:
# 0        2020-01-30
# 1        2020-01-31
# 2        2020-02-01
# 3        2020-02-02
# 4        2020-02-03
#             ...
# 16845    2021-07-07
# 16846    2021-07-07
# 16847    2021-07-07
# 16848    2021-07-07
# 16849    2021-07-07
# Name: Date, Length: 16850, dtype: object

# %%
c_19_IND_df_copy['date'] = pd.to_datetime(c_19_IND_df_copy.Date)

# %%
c_19_IND_df_copy['date']
# Out:
# 0       2020-01-30
# 1       2020-01-31
# 2       2020-02-01
# 3       2020-02-02
# 4       2020-02-03
#            ...
# 16845   2021-07-07
# 16846   2021-07-07
# 16847   2021-07-07
# 16848   2021-07-07
# 16849   2021-07-07
# Name: date, Length: 16850, dtype: datetime64[ns]

# %%
c_19_IND_df_copy['year'] = pd.DatetimeIndex(c_19_IND_df_copy.Date).year

# %%
c_19_IND_df_copy['month'] = pd.DatetimeIndex(c_19_IND_df_copy.Date).month

# %%
c_19_IND_df_copy['day'] = pd.DatetimeIndex(c_19_IND_df_copy.Date).day

# %%
c_19_IND_df_copy['weekday'] = pd.DatetimeIndex(c_19_IND_df_copy.Date).weekday

# %%
c_19_IND_df_copy
# Out:
#          Sno        Date     Time State/UnionTerritory  \
# 0          1  2020-01-30  6:00 PM               Kerala
# 1          2  2020-01-31  6:00 PM               Kerala
# 2          3  2020-02-01  6:00 PM               Kerala
# 3          4  2020-02-02  6:00 PM               Kerala
# 4          5  2020-02-03  6:00 PM               Kerala
# ...      ...         ...      ...                  ...
# 16845  16846  2021-07-07  8:00 AM            Telangana
# 16846  16847  2021-07-07  8:00 AM              Tripura
# 16847  16848  2021-07-07  8:00 AM          Uttarakhand
# 16848  16849  2021-07-07  8:00 AM        Uttar Pradesh
# 16849  16850  2021-07-07  8:00 AM          West Bengal
#
#       ConfirmedIndianNational ConfirmedForeignNational    Cured  Deaths  \
# 0                           1                        0        0       0
# 1                           1                        0        0       0
# 2                           2                        0        0       0
# ...

# %%
march_data = c_19_IND_df_copy[c_19_IND_df_copy.month == 3]

# %%
march_data
# Out:
#          Sno        Date     Time State/UnionTerritory  \
# 31        32  2020-03-01  6:00 PM               Kerala
# 32        33  2020-03-02  6:00 PM            Telengana
# 33        34  2020-03-02  6:00 PM               Kerala
# 34        35  2020-03-02  6:00 PM                Delhi
# 35        36  2020-03-03  6:00 PM            Telengana
# ...      ...         ...      ...                  ...
# 13317  13318  2021-03-31  8:00 AM            Telengana
# 13318  13319  2021-03-31  8:00 AM              Tripura
# 13319  13320  2021-03-31  8:00 AM          Uttarakhand
# 13320  13321  2021-03-31  8:00 AM        Uttar Pradesh
# 13321  13322  2021-03-31  8:00 AM          West Bengal
#
#       ConfirmedIndianNational ConfirmedForeignNational   Cured  Deaths  \
# 31                          3                        0       0       0
# 32                          1                        0       0       0
# 33                          3                        0       0       0
# ...

# %%
march_metrix = march_data[['Confirmed','Cured','Deaths']]
print(march_metrix)
# Out:
#        Confirmed   Cured  Deaths
# 31             3       0       0
# 32             1       0       0
# 33             3       0       0
# 34             1       0       0
# 35             1       0       0
# ...          ...     ...     ...
# 13317     307889  301227    1697
# 13318      33503   33055     392
# 13319     100118   96709    1713
# 13320     615996  598001    8800
# 13321     585933  570303   10327
#
# [1614 rows x 3 columns]

# %%
march_metrix_total = march_metrix.sum()

# %%
march_metrix_total
# Out:
# Confirmed    356315303
# Cured        342611205
# Deaths         4935455
# dtype: int64

# %%
pd.DatetimeIndex(['2020-02-01','2020-03-03','2021-07-07'])
# Out:
# DatetimeIndex(['2020-02-01', '2020-03-03', '2021-07-07'], dtype='datetime64[ns]', freq=None)

# %%
c_19_IND_df_copy['Date']
# Out:
# 0        2020-01-30
# 1        2020-01-31
# 2        2020-02-01
# 3        2020-02-02
# 4        2020-02-03
#             ...
# 16845    2021-07-07
# 16846    2021-07-07
# 16847    2021-07-07
# 16848    2021-07-07
# 16849    2021-07-07
# Name: Date, Length: 16850, dtype: object

# %%
c_19_IND_df_copy['time'] = pd.to_datetime(c_19_IND_df_copy.Time)

# %%
c_19_IND_df_copy['time']
# Out:
# 0       2021-08-04 18:00:00
# 1       2021-08-04 18:00:00
# 2       2021-08-04 18:00:00
# 3       2021-08-04 18:00:00
# 4       2021-08-04 18:00:00
#                 ...
# 16845   2021-08-04 08:00:00
# 16846   2021-08-04 08:00:00
# 16847   2021-08-04 08:00:00
# 16848   2021-08-04 08:00:00
# 16849   2021-08-04 08:00:00
# Name: time, Length: 16850, dtype: datetime64[ns]

# %%
c_19_IND_df_copy['time'].max() , c_19_IND_df_copy['time'].min()
# Out:
# (Timestamp('2021-08-04 21:30:00'), Timestamp('2021-08-04 08:00:00'))

# %%
c_19_IND_df_copy.Time
# Out:
# 0        6:00 PM
# 1        6:00 PM
# 2        6:00 PM
# 3        6:00 PM
# 4        6:00 PM
#           ...
# 16845    8:00 AM
# 16846    8:00 AM
# 16847    8:00 AM
# 16848    8:00 AM
# 16849    8:00 AM
# Name: Time, Length: 16850, dtype: object

# %%
c_19_IND_df_copy['hour'] = pd.DatetimeIndex(c_19_IND_df_copy.Time).hour

# %%
c_19_IND_df_copy['minute'] = pd.DatetimeIndex(c_19_IND_df_copy.Time).minute

# %%
c_19_IND_df_copy.time.dt.hour.head()
# Out:
# 0    18
# 1    18
# 2    18
# 3    18
# 4    18
# Name: time, dtype: int64

# %%
c_19_IND_df_copy.time.dt.dayofyear.tail()
# Out:
# 16845    216
# 16846    216
# 16847    216
# 16848    216
# 16849    216
# Name: time, dtype: int64

# %% [markdown]
# ### to check leap year

# %%
leap_year = pd.date_range("2020-01-30","2024-08-01", freq="Y")
leap_year
# Out:
# DatetimeIndex(['2020-12-31', '2021-12-31', '2022-12-31', '2023-12-31'], dtype='datetime64[ns]', freq='A-DEC')

# %%
leap_year.is_leap_year
# Out:
# array([ True, False, False, False])

# %% [markdown]
# ###  drop columns

# %%
c_19_IND_df_copy.drop('next_day',axis=1,inplace=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-65-68051f47a7b1> in <module>
# ----> 1 c_19_IND_df_copy.drop('next_day',axis=1,inplace=True)
#
# C:\Anaconda\lib\site-packages\pandas\core\frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4161                 weight  1.0     0.8
#    4162         """
# -> 4163         return super().drop(
#    4164             labels=labels,
#    4165             axis=axis,
#
# C:\Anaconda\lib\site-packages\pandas\core\generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3885         for axis, labels in axes.items():
#    3886             if labels is not None:
# -> 3887                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    3888
#    3889         if inplace:
#
# ...

# %%
c_19_IND_df_copy.drop('time',axis=1,inplace=True)

# %%
c_19_IND_df_copy

# %% [markdown]
# ### to check year end..

# %%
month_end = pd.date_range("2020-12-30", periods=3)
month_end

# %%
month_end.is_year_end

# %% [markdown]
# ### for month name

# %%
Month_name = pd.date_range(start='2020-01', freq='Y', periods=8)
Month_name

# %%
Month_name.month_name()

# %% [markdown]
# ### to get day name..

# %%
DAY = pd.date_range(start='2020-03-01', freq='D', periods=8)
DAY

# %%
DAY.day_name()

# %%
c_19_IND_df_copy_month = c_19_IND_df_copy.groupby('month')[['Confirmed','Cured','active_cases','Deaths']].sum()

# %%
c_19_IND_df_copy_month

# %%
c_19_IND_df_copy_month_avg_month_avg = c_19_IND_df_copy.groupby('month')[['Confirmed','Cured','active_cases','Deaths']].agg(np.mean)
c_19_IND_df_copy_month_avg

# %%
c_19_IND_df_copy.Cured.nsmallest(keep='all')

# %%
c_19_IND_df_copy.describe(include='all')

# %%
pd.date_range('2020-03-01','2021-08-01',freq='WOM-3FRI')       ####3RD FRIDAY
# Out:
# DatetimeIndex(['2020-03-20', '2020-04-17', '2020-05-15', '2020-06-19',
#                '2020-07-17', '2020-08-21', '2020-09-18', '2020-10-16',
#                '2020-11-20', '2020-12-18', '2021-01-15', '2021-02-19',
#                '2021-03-19', '2021-04-16', '2021-05-21', '2021-06-18',
#                '2021-07-16'],
#               dtype='datetime64[ns]', freq='WOM-3FRI')
